# %% [markdown]
# # Differnt LLM Frmework and LLM Hosting services

# %% [markdown]
# ## LangChain LLM Integration
# * https://smith.langchain.com/
#
#
#
# ## LiteLLM
# * https://www.litellm.ai/
# * https://docs.litellm.ai/docs/
#
#
# ## Openrouter LLM Integration
#
#
#
# ## Google GenAI API

# %% [markdown]
# # Points from thoughtwork Meeting - AI Coding workflows
#
# ## Coding agent
#   * What is agent.md file
#   * MCP server and context 7 mcp server
#
# ## what is curated shared intructions ?
#   * is this shared prompt which does a specific task nicely ?
#
#
# ## Spec driven development
#
# ## being vigilant and deligent while using I tools
#
#
# ## Language and Frameworks
# ### DeepEval open-source python based (Trial)
#   * Evaludate LLM performace
#   * Unit testing approach
#   * Also supports pytest, featuring to test in CICD
#   * Provides 40+ matrices, also supports RAG
#
# ### G-eval framework
#
# ### Inspect AI
#   * to build for a more regulated AI system
#
#
# ### OpenThread
#   * Open source implemenation of thread protocol
#   * Handy for low power, battery operated devices
#
#
# ### Context Engineering
#   * is it another name for prompt engineering ?
#   * LLM has a huge set of information and context engineering is the instruction that tells llm to narrow the information set to the one which is relevant to user query ?
#
#   #### Context poisioning
#     * What is context poisioning?
#   #### Context confusion and Conflict
#
#   #### HOw to write good effetive prompts.
#     * How to write Minimal system prompts ?
#     * Using few-shots approach.
#
#   #### What is sub-agent and their context window ?
#
#   #### what is Just in time context retrival ?
#
# ### what is Skypilot ?
#
# ### AG-UI Protocol
#   * It has a react implementation library
#
# ### mcp-scan
#
# ### Naive API-to-MCP conversion
